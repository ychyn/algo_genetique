# %% [markdown]
# """
# This is our oroject mainfile
# """

# %% [markdown]
# Modules of python
# -----------------

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from random import randint

# %% [markdown]
# Modules with own classes
# ------------------------

# %%
from glassdata import GlassData
from network import NeuralNetwork

# %% [markdown]
# ---------------------------------------
# Data-set on rho and ANN on molar volume
# ---------------------------------------

# %%
# Dataset of rho
filedbrho='DataBase/rho20oxides.csv'
dbrho=GlassData(filedbrho)
dbrho.info()
dbrho.bounds()
# Out:
# **************
# Finished loading dataset
# Nb of samples: 64421
# Nb of components: 20
# **************
# Finished loading dataset
# Nb of samples: 64421
# Nb of components: 20

# %%
# Determination of the molar volume
dbrho.oxidemolarmass()
dbrho.molarmass()
dbrho.y=dbrho.MolarM/dbrho.y
dbrho.normalize_y()

# %%
# Loading of the ANN model
arch=[20,20,20]
nnmolvol=NeuralNetwork(dbrho.noxide,arch,'gelu','linear')
nnmolvol.compile(3.e-4)
nnmolvol.ArchName(arch)
nnmolvol.load('Models/nnmolarvol'+nnmolvol.namearch+'.h5')
nnmolvol.info()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# **************
# Model: "sequential_181"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_487 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_488 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_489 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_490 (Dense)               │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,283 (5.02 KB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# ------------------------------------------------
# Data-set on Young's modulus and ANN on Vt=E/(2G)
# ------------------------------------------------

# %%
filedbE='DataBase/E20oxides.csv'
dbE=GlassData(filedbE)
dbE.info()
dbE.bounds()
# Out:
# **************
# Finished loading dataset
# Nb of samples: 10846
# Nb of components: 20
# **************
# Finished loading dataset
# Nb of samples: 10846
# Nb of components: 20

# %% [markdown]
# ------------------------------
# Loading of dissociation energy
# ------------------------------

# %%
datadisso=pd.read_csv('dissociationenergy.csv')
G=np.zeros(dbE.nsample)
for i in range(dbE.nsample):
    G[i]=np.sum(datadisso['G'].values*dbE.x[i,:])
#end for

# %%
# Determination of E/G and normalization
dbE.y=dbE.y/(2.*G)
dbE.normalize_y()

# %% [markdown]
# ------------------------------
# Loading of the ANN model on Vt
# ------------------------------

# %%
arch=[20,20,20]
nnmodelEsG=NeuralNetwork(dbE.noxide,arch,'gelu','linear')
nnmodelEsG.compile(1.e-4)
nnmodelEsG.ArchName(arch)
nnmodelEsG.load('Models/nnEsG'+nnmodelEsG.namearch+'.h5')
nnmodelEsG.info()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# **************
# Model: "sequential_262"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_986 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_987 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_988 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_989 (Dense)               │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,283 (5.02 KB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# ---------------------------------------
# Data-set on Tannealing=Tg and ANN model
# ---------------------------------------

# %%
# Data-set of Tannealing
filedbTannealing='DataBase/Tannealing20oxides.csv'
dbTannealing=GlassData(filedbTannealing)
dbTannealing.bounds()
dbTannealing.normalize_y()
# Out:
# **************
# Finished loading dataset
# Nb of samples: 6612
# Nb of components: 20

# %%
# ANN model on Tannealing
# -----------------------
arch=[20,20,20]
nnTannealing=NeuralNetwork(dbTannealing.noxide,arch,'gelu','linear')
nnTannealing.compile(3.e-4)
nnTannealing.ArchName(arch)
nnTannealing.load('Models/nn'+dbTannealing.nameproperty+nnTannealing.namearch+'.h5')
nnTannealing.info()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# **************
# Model: "sequential_187"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_585 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_586 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_587 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_588 (Dense)               │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,283 (5.02 KB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# Data-set on Tmelt
# -----------------

# %%
filedbTmelt='DataBase/Tmelt19oxides.csv'
dbTmelt=GlassData(filedbTmelt)
dbTmelt.info()
dbTmelt.bounds()
dbTmelt.normalize_y()
# Out:
# **************
# Finished loading dataset
# Nb of samples: 5996
# Nb of components: 19
# **************
# Finished loading dataset
# Nb of samples: 5996
# Nb of components: 19

# %%
# ANN model on Tmelt
# ------------------
arch=[20,20,20]
nnTmelt=NeuralNetwork(dbTmelt.noxide,arch,'gelu','linear')
nnTmelt.compile(3.e-4)
nnTmelt.ArchName(arch)
nnTmelt.load('Models/nn'+dbTmelt.nameproperty+nnTmelt.namearch+'.h5')
nnTmelt.info()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# **************
# Model: "sequential_34"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_116 (Dense)               │ (None, 20)             │           400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_117 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_118 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_119 (Dense)               │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,263 (4.94 KB)
#  Trainable params: 1,261 (4.93 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# ------------------------------
# Data-set on Tliq and ANN model
# ------------------------------

# %%
filedbTliq='DataBase\Tsoft20oxides.csv'
dbTliq=GlassData(filedbTliq)
dbTliq.info()
dbTliq.bounds()
dbTliq.normalize_y()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# **************
# Finished loading dataset
# Nb of samples: 12531
# Nb of components: 20
# **************
# Finished loading dataset
# Nb of samples: 12531
# Nb of components: 20
# C:\Users\lucdu\AppData\Local\Temp\ipykernel_2052\4115716478.py:1: SyntaxWarning: invalid escape sequence '\T'
#   filedbTliq='DataBase\Tsoft20oxides.csv'

# %%
# ANN model on Tliq
# -----------------
arch=[32,32,32,32]
nnTliq=NeuralNetwork(dbTliq.noxide,arch,'gelu','linear')
nnTliq.compile(3.e-4)
nnTliq.ArchName(arch)
#modelfile='Models\nn'+dbTliq.nameproperty+nnTliq.namearch+'.h5'
modelfile='Models/nnTsoft3c20.h5'
nnTliq.load(modelfile)
nnTliq.info()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# **************
# Model: "sequential_47"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_172 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_173 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_174 (Dense)               │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_175 (Dense)               │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,283 (5.02 KB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# ------------------------------------------
# Determination of the bounds for each oxide
# ------------------------------------------

# %% [markdown]
# # Algo genetique

# %% [markdown]
# ## Variables utiles

# %%
rho_db = pd.read_csv(r'DataBase\rho20oxides.csv', header=0)
E_db = pd.read_csv('DataBase\\E20oxides.csv', header=0)
Tg_db = pd.read_csv('DataBase\\Tannealing20oxides.csv', header=0)
Tm_db = pd.read_csv('DataBase\\Tmelt19oxides.csv', header=0)

prop_min = np.array([min(rho_db['rho']),min(E_db['E']),min(Tg_db['Tannealing']),min(Tm_db['Tmelt'])])
prop_max = np.array([max(rho_db['rho']),max(E_db['E']),max(Tg_db['Tannealing']),max(Tm_db['Tmelt'])])

print(prop_min,prop_max)
# Out:
# [1789.99996185   37.49200058  549.73444214  961.68375244] [7072.0000267   110.4        1190.15       2053.15061035]

# %%
labels = dbrho.oxide
N_oxides = len(labels)
available_mat = ['SiO2', 'Al2O3', 'MgO', 'CaO', 'Na2O', 'K2O','ZnO', 'TiO2']
prop_label = ['rho','E','Tg','Tmelt']
columns = list(labels)+prop_label+['F']

#Contraintes
xmaxt=np.array([dbrho.xmax,dbE.xmax,dbTannealing.xmax,np.append(dbTmelt.xmax,1.),dbTliq.xmax])
xmax=np.zeros(dbrho.noxide)
for i in range(dbrho.noxide):
    if dbrho.oxide[i] in available_mat:
        xmax[i]=np.min(xmaxt[:,i])

xmin = np.zeros(dbrho.noxide)
xmin[list(dbrho.oxide).index('SiO2')] = 0.5
xmin[list(dbrho.oxide).index('Na2O')] = 0.0

#Parametres fitness function
#L'ordre des parametres est ['rho','E','Tg','Tmelt']
weight=[0,0.1,0,0.9]
minimize=[True,False,False,True]
penalties_onMin = [-np.inf, 50, -np.inf, -np.inf]
penalties_onMax = [np.inf, np.inf, np.inf, 1200]

N_generations = 1600
N_population = 800

survivor_rate = 0.05
parent_rate = 0.5
child_rate = 0.7
mutation_rate = 0
immigration_rate = 1 - survivor_rate - child_rate

strategies = ['China','tournament']
N_tournament = 5
child_strategy = strategies[1]

#population = np.zeros((N_population,len(labels) + len(prop_label) + 1))

N_parents = int(parent_rate * N_population)
N_childs = int(child_rate * N_population)
N_mutants = int(0.1 * N_population)

epsilon = 0.05

# %% [markdown]
# ## Creation de generations

# %%
def prop_calculation(composition):
    rho=dbrho.GlassDensity(nnmolvol,dbrho.oxide,composition)
    E=dbE.YoungModulus(nnmodelEsG,datadisso,dbE.oxide,composition)
    Tg=dbTannealing.physicaly(nnTannealing.model.predict(composition).transpose()[0,:])
    Tmelt=dbTmelt.physicaly(nnTmelt.model.predict(composition[:,:-1]).transpose()[0,:])
    return np.vstack((rho,E,Tg,Tmelt)).transpose()

# %%
def normalize(prop):
    #return (prop - prop.min(axis=0))/(prop.max(axis=0)-prop.min(axis=0))
    return (prop - prop_min)/(prop_max - prop_min)

# %%
penalties_onMin_normalized = normalize(penalties_onMin)
penalties_onMax_normalized = normalize(penalties_onMax)

# %%
def fitness(property_normalized):
    rating = 0
    #print(penalties_onMin_normalized, property_normalized, penalties_onMax_normalized)
    #print(np.all(penalties_onMin_normalized <= property_normalized) and np.all(penalties_onMax_normalized >= property_normalized))
    if np.all(penalties_onMin_normalized <= property_normalized) and np.all(penalties_onMax_normalized >= property_normalized):
        for i in range(len(weight)):
            if minimize[i]:
                rating += (1-property_normalized[i])*weight[i]
            else:
                rating += property_normalized[i]*weight[i]
    return rating

# %%
#prop est une array avec les proprietes du verre normalisées, weight est le poids qu'on accorde
#à chacune des proprietes, et minize est une liste de booléens selon qu'on veuille minimiser
#ou maximiser une certaine variable
'''def fitness_func(prop_normalized,weight,minimize):
    rating = np.zeros(prop_normalized.shape[0])
    for i in range(len(weight)):
        if minimize[i]:
            rating += (1-prop_normalized[:,i])*weight[i]
        else:
            rating += prop_normalized[:,i]*weight[i]
    return rating'''
def fitness_func(prop_normalized):
    return np.apply_along_axis(fitness,1,prop_normalized)

# %%
# Trie la population par F decroissant et renvoie cette population triée avec une nuovelle colonne qui represente 
# le fitness de chaque composition.
def stack_by_f(population,properties,F):
    population_info = np.column_stack((population,properties,F))
    sorted_arr = population_info[population_info[:, -1].argsort()][::-1]
    return sorted_arr

# %%
def init_properties(population):
    prop = prop_calculation(population)
    normalized_prop = normalize(prop)
    F = fitness_func(normalized_prop)
    #print(F)
    sorted_arr = stack_by_f(population, prop, F)
    return sorted_arr

# %%
def compute_properties(generation):
    population_sorted = init_properties(generation[:, :20])
    return population_sorted

# %%
def init_pop(N_population):
    population,_=dbrho.better_random_composition(N_population,xmin,xmax)
    population = init_properties(population)
    return population

# %%
def parent_choice (parents,strategie) :
    #Dans parents chaque individu est représenté par 21 floats dont le dernier est la valeur de fitness
    if strategie =='China' and N_parents>= 2*N_childs:
        dads = parents[::2]
        moms = parents[1::2]
        return (np.array(moms[:N_childs]),np.array(dads[:N_childs]))    
    if strategie =='tournament':
        N_tournament =5
        dads =[]
        moms =[]
        for i in range(N_childs):
            t = np.array([parents[i,:] for i in np.random.choice(N_parents,N_childs)])
            dad = t[np.argmax(t[:N_tournament,-1])]
            mom = t[np.argmax(t[N_tournament:,-1])]
            dads.append(dad)
            moms.append(mom)
        return (np.array(moms),np.array(dads))
    #Fallback
    t = np.array([parents[i] for i in np.random.choice(N_parents,N_childs*2)])
    return (np.array(t[N_childs:]),np.array(t[:N_childs]))

# %%
def population_selection(generation):
    survivors = generation[:int(N_population*survivor_rate)]
    dads,moms = parent_choice(generation,child_strategy)
    #to_be_mutated = sorted_population[int(N_population*survivor_rate):int(N_population*survivor_rate)+int(N_population*mutation_rate)]
    return survivors,dads,moms

# %%
'''def crossover (parents) :
    #Dans parents chaque individu est représenté par 20 premiers floats et le dernier est la valeur de fitness
    childs = np.array([[0.] * len(parents[0])] * N_childs)
    for i in range (N_childs) :
        i1 = randint(0, N_parents-1)
        i2 = randint(0, N_parents-2)
        if i2 == i1 : #problème si deux fois le même parent !!
            i2 += 1
        w1 = parents[i1, -1] / (parents[i1, -1] + parents[i2, -1]) #poids du parent 1
        w2 = parents[i2, -1] / (parents[i1, -1] + parents[i2, -1]) #poids du parent 2
        childs[i] = (w1 * parents[i1] + w2 * parents[i2]) #moyenne pondérée
    return (childs)'''
# Out:
# 'def crossover (parents) :\n    #Dans parents chaque individu est représenté par 20 premiers floats et le dernier est la valeur de fitness\n    childs = np.array([[0.] * len(parents[0])] * N_childs)\n    for i in range (N_childs) :\n        i1 = randint(0, N_parents-1)\n        i2 = randint(0, N_parents-2)\n        if i2 == i1 : #problème si deux fois le même parent !!\n            i2 += 1\n        w1 = parents[i1, -1] / (parents[i1, -1] + parents[i2, -1]) #poids du parent 1\n        w2 = parents[i2, -1] / (parents[i1, -1] + parents[i2, -1]) #poids du parent 2\n        childs[i] = (w1 * parents[i1] + w2 * parents[i2]) #moyenne pondérée\n    return (childs)'

# %%
# températures de fusion des oxydes (en °C) : 
# [1610, 2045, 2852, 2580]
# dureté des oxydes :
# [7, 9, 5.5]
# TiO2 est un agent nucléant utilisé pour les plaques vitrocéramiques (très faible coeff de dilatation thermique).
# source : L'élémentarium

# fondants = ['Na2O', 'K2O', 'MgO']
# stabilisants = ['CaO', 'ZnO']
# ZnO augmente l'élasticité
# source : https://lasirene.e-monsite.com/pages/le-verre/-.html

# formateurs = ['SiO2']
# SiO2 augmente la dureté du verre
# fondants = ['Na2O', 'K2O', 'MgO']
# stabilisants = ['CaO', 'ZnO']
# source : https://infovitrail.com/contenu.php/fr/d/---la-composition-du-verre/e9b609c9-91f5-4a08-86a6-6112dc12b66d

# fondants = ['Na2O', 'K2O'] + ['CaO', 'MgO'] (mais moins bien que les deux premiers)
# modificateurs = ['CaO', 'MgO', 'Al2O3'] #augmentent les propriétés de durabilité chimique et mécanique (E ??)
# formateurs = ['SiO2'] #essentiels
# source : Franck

fondants = [False, False, False, True, True, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False] # diminuent Tm
durability = [True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False] #augmentent E
other = [False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False]

def crossover (mom, dad) :
    childs = np.zeros((len(mom), len(mom[0])))
    for i in range (N_childs) :
        if mom[i, 21] < dad[i, 21] : #choix du meilleur E
            bestE = dad[i]
        else :
            bestE = mom[i]
        if mom[i, 23] < dad[i, 23] : #choix du meilleur Tm
            bestTm = mom[i]
        else :
            bestTm = dad[i]
        childs[i][fondants] = bestTm[fondants]
        childs[i][durability] = bestE[durability]
        childs[i][other] = (mom[i][other] + dad[i][other])/2
        sum = np.sum(childs[i,1:])
        childs[i,1:] = (1-childs[i,0]) * childs[i,1:] / sum
    return (childs)

'''def crossover (mom, dad) :
    childs = np.zeros((len(mom), len(mom[0])))
    for i in range (N_childs) :
        wMomTm = mom[i, 23] / (mom[i, 23] + dad[i, 23])
        wDadTm = dad[i, 23] / (mom[i, 23] + dad[i, 23])
        wMomE = mom[i, 21] / (mom[i, 21] + dad[i, 21])
        wDadE = dad[i, 21] / (mom[i, 21] + dad[i, 21])
        childs[i][fondants] = wMomTm * mom[i][fondants] + wDadTm * dad[i][fondants]
        childs[i][durability] = wMomE * mom[i][durability] + wDadE * dad[i][durability]
        childs[i][other] = (mom[i][other] + dad[i][other])/2
    return (childs)'''
# Out:
# 'def crossover (mom, dad) :\n    childs = np.zeros((len(mom), len(mom[0])))\n    for i in range (N_childs) :\n        wMomTm = mom[i, 23] / (mom[i, 23] + dad[i, 23])\n        wDadTm = dad[i, 23] / (mom[i, 23] + dad[i, 23])\n        wMomE = mom[i, 21] / (mom[i, 21] + dad[i, 21])\n        wDadE = dad[i, 21] / (mom[i, 21] + dad[i, 21])\n        childs[i][fondants] = wMomTm * mom[i][fondants] + wDadTm * dad[i][fondants]\n        childs[i][durability] = wMomE * mom[i][durability] + wDadE * dad[i][durability]\n        childs[i][other] = (mom[i][other] + dad[i][other])/2\n    return (childs)'

# %%
def mutation (mutants) :
    #les mutants sont les meilleures compositions entre 40% et 50%
    for j in range (N_mutants) :
        iplus = randint(0, 19) #choix de l'oxyde qui gagne epsilon
        imoins = randint(0, 19) #choix de l'oxyde qui perd epsilon
        if imoins == iplus : #problème si deux fois le même oxyde !!
            imoins = (1 + imoins)%19
        mutantPlus = mutants[j, iplus]
        mutantMoins = mutants[j, imoins]
        if (mutantMoins > epsilon + xmin[j]) and (mutantPlus < xmax[j] - epsilon) :
            mutants[j, iplus] = mutantPlus + epsilon
            mutants[j, imoins] = mutantMoins - epsilon
    return (mutants)

# %%
def new_generation(old_generation):
    survivors,dads,moms = population_selection(old_generation)
    child = crossover(dads,moms)
    immigrants = init_pop(N_population - (len(survivors) + len(child)))
    new_population = np.vstack((np.vstack((survivors,child)),immigrants))
    new_population = compute_properties(new_population)
    return new_population

# %%
def evolution(generation,N):
    for _ in range(N):
        generation = new_generation(generation)
    return generation

# %%
pop = pd.read_csv('generation_final_oui_le_bon_fin_presque.csv')
pop = pop[pop['SiO2'] > 0.5]
pop = pop.to_numpy()
pop = np.delete(pop, 0, 1)
np.shape(pop)
reste = N_population - np.shape(pop)[0]
new = init_pop(reste)
pop = np.vstack((pop, new))
np.shape(pop)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (800, 25)

# %%
#initial_pop = init_pop(N_population)
compositions = evolution(pop,N_generations)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 289us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 230us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 287us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 290us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 151us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 347us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 244us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 267us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 284us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 281us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 251us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 86us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 118us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 78us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 87us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 204us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 89us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 87us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 281us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 98us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 206us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 290us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 267us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 174us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 344us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 241us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 283us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/stepe
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 104us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 113us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 287us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 255us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ...
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 115us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 99us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 91us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 132us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 211us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 104us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 130us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
df = pd.DataFrame(compositions,columns=columns)
df.to_csv('generation_final_oui_le_bon_oui.csv')
df
#df.to_csv('generation_final_29_11b.csv')
# Out:
#          SiO2  B2O3         Al2O3       MgO           CaO  BaO  Li2O  \
# 0    0.500072   0.0  8.139910e-14  0.000057  1.408659e-13  0.0   0.0
# 1    0.500072   0.0  8.139910e-14  0.000057  1.408659e-13  0.0   0.0
# 2    0.500072   0.0  8.139910e-14  0.000057  1.408659e-13  0.0   0.0
# 3    0.500072   0.0  8.139910e-14  0.000057  1.408659e-13  0.0   0.0
# 4    0.500072   0.0  8.139910e-14  0.000057  1.408659e-13  0.0   0.0
# ..        ...   ...           ...       ...           ...  ...   ...
# 795  0.676231   0.0  1.543544e-01  0.000096  1.112965e-01  0.0   0.0
# 796  0.767227   0.0  3.208474e-04  0.008929  5.711933e-02  0.0   0.0
# 797  0.754533   0.0  5.906048e-04  0.024118  3.121956e-02  0.0   0.0
# 798  0.813606   0.0  7.370159e-02  0.000040  2.754020e-03  0.0   0.0
# 799  0.807638   0.0  1.237951e-03  0.072511  1.066980e-02  0.0   0.0
#
#              Na2O           K2O       ZnO  ...      TiO2  GeO2  ZrO2  P2O5  \
# 0    1.811018e-01  2.417677e-01  0.065217  ...  0.011784   0.0   0.0   0.0
# 1    1.811018e-01  2.417677e-01  0.065217  ...  0.011784   0.0   0.0   0.0
# 2    1.811018e-01  2.417677e-01  0.065217  ...  0.011784   0.0   0.0   0.0
# 3    1.811018e-01  2.417677e-01  0.065217  ...  0.011784   0.0   0.0   0.0
# 4    1.811018e-01  2.417677e-01  0.065217  ...  0.011784   0.0   0.0   0.0
# ..            ...           ...       ...  ...       ...   ...   ...   ...
# 795  2.000626e-02  1.299836e-05  0.000888  ...  0.037115   0.0   0.0   0.0
# 796  5.937036e-11  2.123423e-06  0.159227  ...  0.007175   0.0   0.0   0.0
# 797  4.823869e-04  1.955247e-02  0.107013  ...  0.062491   0.0   0.0   0.0
# 798  2.414720e-05  6.039432e-08  0.015098  ...  0.094776   0.0   0.0   0.0
# 799  8.648762e-03  9.143182e-06  0.001064  ...  0.098221   0.0   0.0   0.0
#
#      V2O5          rho          E           Tg        Tmelt         F
# 0     0.0  2669.878389  53.759969   611.528564   995.424011  0.894492
# 1     0.0  2669.878389  53.759969   611.528564   995.424011  0.894492
# 2     0.0  2669.878389  53.759969   611.528564   995.424011  0.894492
# 3     0.0  2669.878389  53.759969   611.528564   995.424011  0.894492
# 4     0.0  2669.878389  53.759969   611.528564   995.424011  0.894492
# ..    ...          ...        ...          ...          ...       ...
# 795   0.0  2525.001870  85.818992  1101.384277  2145.553467 -0.009909
# 796   0.0  2678.359958  81.629198   994.994629  2144.260498 -0.014589
# 797   0.0  2613.466823  73.757461   985.251892  2151.204834 -0.031112
# 798   0.0  2359.034000  73.951189  1140.834717  2497.465576 -0.316365
# 799   0.0  2400.152747  76.093014   940.895447  2739.218750 -0.512772
#
# [800 rows x 25 columns]
